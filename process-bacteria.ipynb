# %% [markdown]
# # Process Bacteria
#
# ... description of the notebook goes here ...
#
# ### Prerequisites:
# - conda (Miniconda or Anaconda): https://conda.io/projects/conda/en/latest/user-guide/install/index.html
# - scikit-bio: `conda install -c https://conda.anaconda.org/biocore scikit-bio`
# - prophage tools & their setup (follow instructions in section 2.)

# %% [markdown]
# ## 1. Notebook Setup
#
# Import the necessary libraries and set the data & output paths

# %%
import os
import shutil
import subprocess
from pathlib import Path

import skbio

# %%
# Path to the folder containing genomic data (relative to current working directory)
data_dir = Path(Path.cwd(), '..', 'data')
data_dir.mkdir(exist_ok=True)
(data_dir / 'compressed').mkdir(exist_ok=True)

# Path to the output folder
out_dir = Path(Path.cwd(), '..', 'out')
out_dir.mkdir(exist_ok=True)

# %% [markdown]
# ## 2. Prophage Tool Setup
#
# Select prophage CLI tools you intend to use. The recommended ones include:
#
#  - PhageBoost: https://github.com/ku-cbd/PhageBoost
#  - PhiSpy: https://github.com/linsalrob/PhiSpy
#
# For each tool:
#
#  1. Create new conda enviroment: `conda create -n [name_of_the_tool]`
#  1. Install the tool and its prerequisites according to author's instructions
#  1. Register the path to the binary and arguments the tool should be invoked with using the function below:

# %%
tools = []

def register_tool(tool_name, tool_path, input_arg, output_arg, tool_input_type='fasta', separate_subsequences=False, **cli_args):
    def invoke_tool(inp, out):
        return f'{tool_path} {input_arg} {inp} {output_arg} {out} {" ".join([f"--{f} {a}" for f, a in cli_args.items()])}'
    tools.append({
        'name': tool_name,
        'input_type': tool_input_type,
        'separate_subsequences': separate_subsequences,
        'cli_call': invoke_tool
    })

# Register tools here
register_tool('PhageBoost',
    tool_path='~/miniconda3/envs/phage-boost/bin/PhageBoost',
    input_arg='-f',
    output_arg='-o',
    # Other args go here
)

register_tool('PhiSpy',
    tool_input_type='gb',
    tool_path='~/miniconda3/envs/phispy/bin/PhiSpy.py',
    input_arg='',
    output_arg='-o',
    # Other args go here
)

# %% [markdown]
# ## 3. Data extraction
#
# Download genomic data for the bacteria of interest from [NCBI Assembly](https://www.ncbi.nlm.nih.gov/assembly) in fasta (.fna) and genbank (.gbff) formats. Name them "[taxid]_(fasta|gb).tar" and put them in "compressed" folder in your data folder, then run the following code:

# %%
# Change to True to extract data anew
overwrite_data = False

# 1.c decompress all downloaded assemblies
for entry in os.scandir(data_dir / 'compressed'):
    if entry.is_file():
        taxid, file_type = entry.name.split('.')[0].split('_')
        file_path = data_dir / taxid / file_type

        if file_path.exists():
            if overwrite_data:
                shutil.rmtree(file_path)
            else:
                continue

        file_path.mkdir(exist_ok=True, parents=True)

        # Run tar command in a subprocess to extract the archive
        subprocess.run(['tar', '-xf', entry.path, '-C', file_path, '--strip-components', '1'])

        # Unzip all extracted files
        for f in os.scandir(file_path):
            if (f.path.endswith('.gz')):
               subprocess.run(['gzip', '-d', f.path])
                # Rename the files to include only assembly accession id
               f_path = Path(f.path.replace('.gz', ''))
               f_path.rename(f_path.parents[0] / ('_'.join(f_path.stem.split('_')[:2]) + f_path.suffix))
            else:
                # Remove files that don't contain genomic sequences
                os.remove(f.path)

# %% [markdown]
# ### 3.1 Flatten FASTA files
#
# Many tools work better with only one sequence per fasta file, so we need to split the files with multiple sequences into individual ones:

# %%
for entry in os.scandir(data_dir):
    fasta_dir = Path(entry.path, 'fasta')
    if entry.is_dir() and fasta_dir.exists():
        for f in os.scandir(fasta_dir):
            if not f.is_file():
                continue
            
            f_path = Path(f.path)
            dir_path = (f_path.parents[0] / f_path.stem)
            dir_path.mkdir(exist_ok=True)

            for seq in skbio.io.read(str(f_path), format='fasta'):
                seq.write(str(dir_path / (seq.metadata['id'] + '.fasta')), format='fasta')
            
            os.remove(f_path)

# %% [markdown]
# ## 4. Run the tools
#
# Predict the prophages from the data sequences and save the results in \[output_folder\]/\[tool_name\]/\[taxid\]/\[assembly_accession\]/:

# %%
# Change to True to process data anew
overwrite_output = True

for tool in tools:
    for entry in os.scandir(data_dir):
        # Use only data in the correct format for the tool
        seq_dir = Path(entry.path, tool['input_type'])
        if entry.is_dir() and seq_dir.exists():
            for assembly in os.scandir(seq_dir):
                print(assembly.path)
                print('\n')

                # Create output path
                tool_out_path = out_dir / tool['name'] / entry.name / '.'.join(assembly.name.split('.')[:2])
                if tool_out_path.exists():
                    if overwrite_output or not (tool_out_path / '.done').exists():
                        shutil.rmtree(tool_out_path)
                    else:
                        print('\n--------------------------------------------------\n')
                        continue

                tool_out_path.mkdir(exist_ok=True, parents=True)

                # Run the tool
                if assembly.is_file():
                    # !{tool['cli_call'](assembly.path, str(tool_out_path))}
                elif assembly.is_dir():
                    for f in os.scandir(assembly.path):
                        # !{tool['cli_call'](f.path, str(tool_out_path / '.'.join(f.name.split('.')[:-1])) if tool['separate_subsequences'] else str(tool_out_path))}

                # Mark as done
                (tool_out_path / '.done').touch()
                print('\n--------------------------------------------------\n')
# Out:
# ing_model.html
# time after predictions: 2.2317392826080322
# {}
# no phages found
# processing: WOUN01000007
# time after genecalls: 0.13173556327819824
# time after feature calculations: 0.4884936809539795
# [11:51:49] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.0665030479431152
# {}
# no phages found
# processing: WOUN01000001
# time after genecalls: 1.5512664318084717
# time after feature calculations: 4.097052574157715
# [11:51:56] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 5.723111152648926
# {}
# no phages found
# processing: WOUN01000002
# time after genecalls: 1.9734890460968018
# time after feature calculations: 5.288930416107178
# [11:52:04] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 6.832658052444458
# {'phage0': 12}
# processing: WOUN01000003
# time after genecalls: 0.2137138843536377
# time after feature calculations: 0.6973423957824707
# [11:52:07] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.1347999572753906
# {}
# no phages found
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/556287/fasta/GCA_001414235.1
#
#
# processing: LLVZ01000025
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000015
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000014
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000020
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000013
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000011
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000018
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000012
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000021
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000002
# time after genecalls: 1.0035679340362549
# time after feature calculations: 2.8746633529663086
# [11:52:23] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 4.5312535762786865
# {}
# no phages found
# processing: LLVZ01000017
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000024
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000023
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000005
# time after genecalls: 0.3006019592285156
# time after feature calculations: 0.9276340007781982
# [11:52:30] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.4733359813690186
# {}
# no phages found
# processing: LLVZ01000003
# time after genecalls: 0.667978048324585
# time after feature calculations: 1.8323523998260498
# [11:52:35] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 3.400373697280884
# {'phage1': 16, 'phage2': 12}
# processing: LLVZ01000026
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000009
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000019
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000016
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000007
# time after genecalls: 0.18677854537963867
# time after feature calculations: 0.640134334564209
# [11:52:43] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.2440340518951416
# {}
# no phages found
# processing: LLVZ01000010
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000022
# after min_size_of_contig 10000, no contigs were left. This caused the run to fail
# processing: LLVZ01000004
# time after genecalls: 0.4871096611022949
# time after feature calculations: 1.4051463603973389
# [11:52:50] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 3.055051803588867
# {}
# no phages found
# processing: LLVZ01000008
# time after genecalls: 0.127166748046875
# time after feature calculations: 0.4412209987640381
# [11:52:53] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.0777218341827393
# {}
# no phages found
# processing: LLVZ01000006
# time after genecalls: 0.17569613456726074
# time after feature calculations: 0.6827223300933838
# [11:52:56] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 2.2997758388519287
# {}
# no phages found
# processing: LLVZ01000001
# time after genecalls: 1.0198509693145752
# time after feature calculations: 3.0593671798706055
# [11:53:02] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 4.5879902839660645
# {}
# no phages found
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/28105/fasta/GCA_002197105.1
#
#
# processing: CP021826
# time after genecalls: 0.7701220512390137
# time after feature calculations: 2.0000319480895996
# [11:53:07] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 3.615894079208374
# {}
# no phages found
# processing: CP021828
# time after genecalls: 7.051033020019531
# time after feature calculations: 17.114713668823242
# [11:53:27] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 18.729459762573242
# {}
# no phages found
# processing: CP021827
# time after genecalls: 5.663811922073364
# time after feature calculations: 13.841742038726807
# [11:53:43] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 15.548301219940186
# {}
# no phages found
# processing: CP021825
# time after genecalls: 15.741645097732544
# time after feature calculations: 38.31173658370972
# [11:54:24] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 40.0517942905426
# {'phage1': 11}
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/1273132/fasta/GCA_000325745.1
#
#
# processing: CP003789
# time after genecalls: 4.89551043510437
# time after feature calculations: 14.210298299789429
# [11:54:42] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 15.830983638763428
# {'phage0': 27, 'phage3': 20}
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/234/fasta/GCA_014884505.1
#
#
# processing: CP054955
# time after genecalls: 9.089780807495117
# time after feature calculations: 20.997640132904053
# [11:55:06] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 22.662135124206543
# {'phage0': 21}
# processing: CP054956
# time after genecalls: 6.388880014419556
# time after feature calculations: 15.030055046081543
# [11:55:23] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 16.706812858581543
# {}
# no phages found
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/34020/fasta/GCA_001021085.1
#
#
# processing: CP004021
# time after genecalls: 3.869270086288452
# time after feature calculations: 11.029396295547485
# [11:55:37] WARNING: ../src/tree/./updater_quantile_hist.h:135: Attempted to load internal configuration for a model file that was generated by a previous version of XGBoost. A likely cause for this warning is that the model was saved with saveRDS() in R or pickle.dump() in Python. We strongly ADVISE AGAINST using saveRDS() or pickle.dump() so that the model remains accessible in current and upcoming XGBoost releases. Please use xgb.save() instead to preserve models for the long term. For more details and explanation, see https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
# time after predictions: 12.729522228240967
# {'phage1': 28, 'phage2': 22}
#
# --------------------------------------------------
#
# /home/chris/prophage-tool/notebooks/../data/773/gb/GCA_002007505.1.gbff
#
#
# Making Test Set...
# Start Classification Algorithm...
# As training flag is zero, considering unknown functions
# Evaluating...
# Checking prophages in initial_tbl.tsv
#
# Potential prophages (sorted highest to lowest)
# Contig	Start	Stop	Number of potential genes	Status
# CP015821.1	594334	639376	48	Kept
# CP015821.1	1563440	1602516	46	Kept
# CP015821.1	1993944	2031362	36	Kept
# CP015821.1	2324391	2351733	12	Kept
# CP015821.1	1236059	1243914	5	Kept
# CP015821.1	2578155	2582098	2	Dropped. Not enough genes
# CP015821.1	32943	33881	1	Dropped. Not enough genes
# CP015821.1	1297830	1298138	1	Dropped. Not enough genes
# CP015821.1	2267984	2268391	1	Dropped. Not enough genes
# CP015821.1	2512370	2513323	1	Dropped. Not enough genes
#
# PROPHAGE: 1 Contig: CP015821.1 Start: 594334 Stop: 639376
# PP: 1 start: 594334 stop: 639376
# Finding repeats in pp 1 from 592334 to 641376
# There were 3 repeats with the same length as the best. One chosen somewhat randomly!
# PROPHAGE: 2 Contig: CP015821.1 Start: 1236059 Stop: 1243914
# PP: 2 start: 1236059 stop: 1243914
# Finding repeats in pp 2 from 1234059 to 1245914
# PROPHAGE: 3 Contig: CP015821.1 Start: 1563440 Stop: 1602516
# PP: 3 start: 1563440 stop: 1602516
# Finding repeats in pp 3 from 1561440 to 1604516
# There were 9 repeats with the same length as the best. One chosen somewhat randomly!
# PROPHAGE: 4 Contig: CP015821.1 Start: 1993944 Stop: 2031362
# PP: 4 start: 1993944 stop: 2031362
# Finding repeats in pp 4 from 1991944 to 2033362
# There were 25 repeats with the same length as the best. One chosen somewhat randomly!
# PROPHAGE: 5 Contig: CP015821.1 Start: 2324391 Stop: 2351733
# PP: 5 start: 2324391 stop: 2351733
# Finding repeats in pp 5 from 2322391 to 2353733
# Done!!!
#
# --------------------------------------------------
